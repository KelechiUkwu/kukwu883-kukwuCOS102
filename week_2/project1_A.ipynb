# %% [markdown]
# ![Checkout](checkout.png)
#
# Flowchart to show the checkout process at a store

# %% [raw]
# BEGIN  THE CHECKOUT PROCESS FROM THE STORE
# INSERT  UNLOAD THE ITEMS FOR SCAN
# INSERT  SCAN THE ITEMS
# COMPUTE  THE TOTAL PRICE OF THE GOODS
# DISPLAY  THE FINAL COST OF THE GOODS
# IF  INSUFFICIENT FUNDS, REMOVE SOME ITEMS OR RESOLVE PAYMENT ISSUES
# PRINT  RECEIPT
# END  CHECKOUT
